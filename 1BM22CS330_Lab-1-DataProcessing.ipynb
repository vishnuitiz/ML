# %%
import pandas as pd

# %%
data=pd.read_csv("/Dataset of Diabetes .csv")
df1=pd.DataFrame(data)
print(df1)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# 2    24.0     N
# 3    24.0     N
# 4    21.0     N
# ..    ...   ...
# 995  30.0     Y
# 996  37.2    Y
# 997  27.4    Y
# 998  40.5    Y
# 999  33.0    Y
#
# [1000 rows x 14 columns]

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
df1['Gender']= label_encoder.fit_transform(df1['Gender'])

df1['Gender'].unique()
# Out:
# array([0, 1, 2])

# %%
def drop_outliers_IQR(df1):
   q1=df1["AGE"].quantile(0.25)
   q3=df1["AGE"].quantile(0.75)
   IQR=q3-q1
   not_outliers = df[~((df<(q1-1.5*IQR)) | (df>(q3+1.5*IQR)))]
   outliers_dropped = outliers.dropna().reset_index()
   return outliers_dropped

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from scipy import stats

# %%
normalizer = MinMaxScaler()
df1[['AGE']] = normalizer.fit_transform(df1[['AGE']])
df1.head()


scaler = StandardScaler()
df1[['AGE']] = scaler.fit_transform(df1[['AGE']])
df1.head()
# Out:
#     ID  No_Pation  Gender       AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  \
# 0  502      17975       0 -0.401144   4.7  46    4.9   4.2  0.9  2.4  1.4
# 1  735      34221       1 -3.130017   4.5  62    4.9   3.7  1.4  1.1  2.1
# 2  420      47975       0 -0.401144   4.7  46    4.9   4.2  0.9  2.4  1.4
# 3  680      87656       0 -0.401144   4.7  46    4.9   4.2  0.9  2.4  1.4
# 4  504      34223       1 -2.334096   7.1  46    4.9   4.9  1.0  0.8  2.0
#
#    VLDL   BMI CLASS
# 0   0.5  24.0     N
# 1   0.6  23.0     N
# 2   0.5  24.0     N
# 3   0.5  24.0     N
# 4   0.4  21.0     N
